# %% [markdown]
# ### <ins>Data Exploration & Analysis of Heart Failture Clinical Dataset<ins>
# #### https://archive.ics.uci.edu/ml/datasets/Heart+failure+clinical+records

# %% [markdown]
# ### Please Watch Video Presentation of This Project Here: https://vimeo.com/632205031

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import matplotlib.mlab as mlab

# %% [markdown]
# ### Load Data

# %%
HeartFail = pd.read_csv('../../Data/heart_failure_clinical_records_dataset (1).csv')

# %%
HeartFail.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# #### <ins>Column Key<ins>
# #### Thirteen (13) clinical features:
#
# - age: age of the patient (years)
# - anaemia: decrease of red blood cells or hemoglobin (boolean)
# - high blood pressure: if the patient has hypertension (boolean)
# - creatinine phosphokinase (CPK): level of the CPK enzyme in the blood (mcg/L)
# - diabetes: if the patient has diabetes (boolean)
# - ejection fraction: percentage of blood leaving the heart at each contraction (percentage)
# - platelets: platelets in the blood (kiloplatelets/mL)
# - sex: woman or man (binary)
# - serum creatinine: level of serum creatinine in the blood (mg/dL)
# - serum sodium: level of serum sodium in the blood (mEq/L)
# - smoking: if the patient smokes or not (boolean)
# - time: follow-up period (days)
# - [target] death event: if the patient deceased during the follow-up period (boolean)
#
# ####### sited from website: https://archive.ics.uci.edu/ml/datasets/Heart+failure+clinical+records

# %% [markdown]
# #### Interested in Looking at the trends in the data in relation to gender:

# %%
HeartFail[['sex']].value_counts()
# Out:
# sex
# 1      194
# 0      105
# dtype: int64

# %% [markdown]
# #### There are much less women in the study than men: 105 women and 194 men.

# %% [markdown]
# #### <ins>Correlation Matrix<ins>

# %%
HeartFail.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_6694f_row0_col0, #T_6694f_row1_col1, #T_6694f_row2_col2, #T_6694f_row3_col3, #T_6694f_row4_col4, #T_6694f_row5_col5, #T_6694f_row6_col6, #T_6694f_row7_col7, #T_6694f_row8_col8, #T_6694f_row9_col9, #T_6694f_row10_col10, #T_6694f_row11_col11, #T_6694f_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_6694f_row0_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col3, #T_6694f_row2_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col4, #T_6694f_row1_col0, #T_6694f_row4_col5, #T_6694f_row5_col12 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col5, #T_6694f_row4_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_6694f_row0_col6, #T_6694f_row8_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col7, #T_6694f_row12_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_6694f_row0_col8, #T_6694f_row2_col7, #T_6694f_row7_col2, #T_6694f_row10_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col9, #T_6694f_row4_col1, #T_6694f_row8_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6694f_row0_col10, #T_6694f_row1_col8, #T_6694f_row5_col1, #T_6694f_row8_col1, #T_6694f_row11_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col11, #T_6694f_row1_col2, #T_6694f_row2_col1, #T_6694f_row3_col9, #T_6694f_row4_col12, #T_6694f_row5_col11, #T_6694f_row6_col9, #T_6694f_row7_col8, #T_6694f_row8_col12, #T_6694f_row9_col3, #T_6694f_row10_col3, #T_6694f_row11_col12, #T_6694f_row12_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6694f_row0_col12, #T_6694f_row12_col1 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_6694f_row1_col3, #T_6694f_row2_col3, #T_6694f_row2_col11, #T_6694f_row7_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col4, #T_6694f_row5_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col5, #T_6694f_row5_col8, #T_6694f_row6_col3, #T_6694f_row8_col5, #T_6694f_row9_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col6, #T_6694f_row2_col4, #T_6694f_row7_col6, #T_6694f_row8_col0, #T_6694f_row9_col11 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col7, #T_6694f_row5_col6, #T_6694f_row9_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col9, #T_6694f_row10_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col10, #T_6694f_row6_col12, #T_6694f_row10_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6694f_row1_col12, #T_6694f_row3_col6, #T_6694f_row8_col6, #T_6694f_row11_col5, #T_6694f_row12_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6694f_row2_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6694f_row2_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6694f_row2_col8, #T_6694f_row4_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6694f_row2_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_6694f_row2_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_6694f_row2_col12, #T_6694f_row8_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col1, #T_6694f_row3_col2, #T_6694f_row3_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col4, #T_6694f_row9_col12, #T_6694f_row10_col2, #T_6694f_row10_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col7, #T_6694f_row4_col9 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col10, #T_6694f_row9_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col11, #T_6694f_row6_col8, #T_6694f_row7_col9, #T_6694f_row8_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6694f_row3_col12, #T_6694f_row6_col2, #T_6694f_row6_col10, #T_6694f_row7_col10 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6694f_row4_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6694f_row4_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6694f_row4_col7, #T_6694f_row7_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6694f_row4_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6694f_row4_col10, #T_6694f_row5_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_6694f_row4_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6694f_row5_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6694f_row5_col2, #T_6694f_row10_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6694f_row5_col3, #T_6694f_row6_col5, #T_6694f_row7_col5, #T_6694f_row10_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6694f_row5_col9, #T_6694f_row6_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6694f_row5_col10, #T_6694f_row6_col11, #T_6694f_row7_col3, #T_6694f_row10_col12 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6694f_row6_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6694f_row6_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6694f_row6_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6694f_row7_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_6694f_row7_col11, #T_6694f_row10_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6694f_row7_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_6694f_row8_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_6694f_row8_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_6694f_row8_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6694f_row9_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6694f_row9_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6694f_row9_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6694f_row9_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6694f_row9_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6694f_row9_col10 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_6694f_row10_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_6694f_row10_col11 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6694f_row11_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_6694f_row11_col2, #T_6694f_row12_col10 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6694f_row11_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_6694f_row11_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_6694f_row11_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_6694f_row11_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_6694f_row11_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_6694f_row11_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6694f_row11_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6694f_row12_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_6694f_row12_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_6694f_row12_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6694f_row12_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_6694f_row12_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_6694f_row12_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_6694f_row12_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# </style>
# <table id="T_6694f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6694f_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_6694f_level0_col1" class="col_heading level0 col1" >anaemia</th>
#       <th id="T_6694f_level0_col2" class="col_heading level0 col2" >creatinine_phosphokinase</th>
#       <th id="T_6694f_level0_col3" class="col_heading level0 col3" >diabetes</th>
#       <th id="T_6694f_level0_col4" class="col_heading level0 col4" >ejection_fraction</

# %% [markdown]
# #### <ins>Heat Map<ins>

# %%
plt.figure(figsize=(16,14))
sns.heatmap(HeartFail.corr(), cmap ="YlGnBu",linewidths = .1, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <ins>Cluster Map<ins>

# %%
plt.figure(figsize=(20,14))
sns.clustermap(HeartFail.corr(), cmap ="YlGnBu",linewidths = .1, annot = True)

# %% [markdown]
# #### <ins>Pairplots<ins>

# %%
sns.pairplot(HeartFail)

# %% [markdown]
# #### <ins>Bar Graphs<ins>

# %%
fig, axes = plt.subplots(2, 3, figsize = (14, 9), sharey = True)
HeartFail.anaemia.value_counts().plot.bar(title = 'Anaemia', color= "maroon", ax=axes[0,0])
HeartFail.diabetes.value_counts().plot.bar(title ='Diabetes', ax=axes[0,1])
HeartFail.high_blood_pressure.value_counts().plot.bar(title = 'High Blood Pressure', color= "teal", ax=axes[0,2])
HeartFail.sex.value_counts().plot.bar(title = 'Gender', color="purple", ax=axes[1,0])
HeartFail.smoking.value_counts().plot.bar(title = 'Smoking', color= "green", ax=axes[1,1])
HeartFail.DEATH_EVENT.value_counts().plot.bar(title = 'Death Event', color= "orange", ax=axes[1,2])
for ax in fig.axes:
    ax.tick_params(labelrotation=0)

# %% [markdown]
# #### This data shows that quite a significant amount of people had anaemia. Several people had diabetes and high blood pressure. There are much more nonsmokers than smokers. There are significantly more males than females in the study. And thankfully, more people lived than died.

# %%
sns.displot(HeartFail, x= 'age', hue = 'sex', col = 'smoking', kind='hist')

# %% [markdown]
# #### Graphs show the age range of men and women as well as if they are smokers. The data shows much more male smokers than female smokers, yet we saw above that there were significantly more men in the study than women so that may be one reason for this result.

# %%
plt.figure(figsize = (13, 5))
sns.histplot(data = HeartFail, x = 'age', hue='DEATH_EVENT', multiple= 'stack')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# #### Graph shows age and death events.

# %%
plt.figure(figsize = (15, 7))
plt.axvline(1.04, color = 'red')
plt.axvline(1.35, color = 'blue')
plt.axvline(.74, color = 'red')
plt.axvline(.59, color = 'blue')
sns.histplot(HeartFail, x= 'serum_creatinine', kde = True, hue='sex', color ='orange')
#This shows serum creatinine normal ranges for both men (blue lines) and women (red lines)
# Out:
# <AxesSubplot:xlabel='serum_creatinine', ylabel='Count'>

# %% [markdown]
# #### This graph shows serum creatinine levels for both men and women. The normal range for women is shown in the graph between the red lines at .74-1.04 mg/dL, and the normal range for men is shown inbetween the blue lines at .59-1.35mg/dL.
# ####Resources for serum creatinine: https://www.mayoclinic.org/tests-procedures/creatinine-test/about/pac-20384646

# %%
plt.figure(figsize = (10, 6))
plt.axvline(50, color ='red')
plt.axvline(70, color ='red')
sns.histplot(HeartFail, x= 'ejection_fraction', kde = True, hue='sex', color ='orange')
# Out:
# <AxesSubplot:xlabel='ejection_fraction', ylabel='Count'>

# %% [markdown]
# #### The above graph shows the normal range of ejection fraction is between the two red lines between 50 and 70%. This graph shows that most people in this dataset were well below the normal ejection fraction range. Anything below 40% can be an indicator of heart failure.
# #### Source on ejection fraction:https://www.heart.org/en/health-topics/heart-failure/diagnosing-heart-failure/ejection-fraction-heart-failure-measurement

# %%
plt.figure(figsize = (10, 6))
plt.axvline(135, color ='red')
plt.axvline(145, color ='red')
sns.histplot(HeartFail, x= 'serum_sodium', kde = True, hue='sex', color ='orange')
# Out:
# <AxesSubplot:xlabel='serum_sodium', ylabel='Count'>

# %% [markdown]
# #### The above graph shows the normal range for serum sodium indicated inbetween the red lines at 135-145 mEq/L. Most of the patients in this dataset were in the normal range. Anything under 135 can indicate hyponatremia as sodium is diluted from the body.
# ####Source for serum sodium:https://www.mayoclinic.org/diseases-conditions/hyponatremia/symptoms-causes/syc-20373711

# %%
plt.figure(figsize = (15, 7))
plt.axvline(10, color ='red')
plt.axvline(120, color ='red')
sns.histplot(HeartFail.creatinine_phosphokinase, kde = True)

#This shows creatinine phosphokinase normal range of 10- 120 mcg/L in men and women
# Out:
# <AxesSubplot:xlabel='creatinine_phosphokinase', ylabel='Count'>

# %% [markdown]
# #### Above graph looks at creatinine phosphokinase levels overall, while the below graph adds the gender variable.

# %%
plt.figure(figsize = (15, 7))
plt.axvline(10, color ='red')
plt.axvline(120, color ='red')
sns.histplot(HeartFail, x= 'creatinine_phosphokinase', kde = True, hue='sex')
#sns.histplot(HeartFail, x= 'serum_sodium', kde = True, hue='sex', color ='orange')
# Out:
# <AxesSubplot:xlabel='creatinine_phosphokinase', ylabel='Count'>

# %% [markdown]
# #### The above graph shows the normal range of creatinine phosphokinase inbetween 10 and 120  mcg/L. This data shows quite a bit of patients were outside the normal range here.

# %% [markdown]
# ### https://www.ucsfhealth.org/medical-tests/creatine-phosphokinase-test

# %%
plt.figure(figsize = (15, 7))
plt.axvline(450000, color = 'purple')
plt.axvline(150000, color = 'purple')
plt.axvline(135000, color = 'blue')
plt.axvline(317000, color = 'blue')
plt.axvline(157000, color = 'red')
plt.axvline(371000, color = 'red')
sns.histplot(HeartFail, x= 'platelets', kde = True, hue='sex', color ='orange')
#This shows platelets normal ranges for both men (blue lines) and women (red lines) as well as danger zones below the purple line on the left and to the right of the purple line on the right.
# Out:
# <AxesSubplot:xlabel='platelets', ylabel='Count'>

# %% [markdown]
# #### Graph shows the normal range of platelet counts for women in between the red lines between 157,000 and 371,000 microliters of blood so most of the women in this study were in the normal range. In between the blue lines at 135,000 to 317,000 represents the normal range for men and most of the men in this study were in the normal range. The purple lines represent the point at which going below 150,000 platelet count or above 450,000 can be critical. To the left of the first purple line indicates a platelet count lower than 150,000 which can cause internal bleeding. A platelet count higher than 450,000 to the right of the second purple line indicates potiential blood clot issues.
# #### https://www.oneblood.org/media/blog/platelets/what-is-a-normal-platelet-count.stml

# %%
sns.boxplot(x=HeartFail.DEATH_EVENT, y=HeartFail.serum_creatinine)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='serum_creatinine'>

# %% [markdown]
# #### This box plot shows that there were there is higher serum creatinine levels there can be more chance for a death event in this dataset.

# %%
sns.violinplot(x=HeartFail.DEATH_EVENT, y=HeartFail.age, hue=HeartFail.sex, split=True)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='age'>

# %% [markdown]
# #### This is a violin plot that shows age and gender in whether or not there was a death event. It makes sense that the death event plot on the right is a little higher that the survival plot on the left because as people age in general there is a greater chance of mortality.

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 10))

sns.histplot(data=HeartFail, x="age", kde=True, color="skyblue", ax=axs[0, 0])
sns.histplot(data=HeartFail, x="creatinine_phosphokinase", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=HeartFail, x="ejection_fraction", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=HeartFail, x="platelets", kde=True, color="teal", ax=axs[1, 1])
sns.histplot(data=HeartFail, x="serum_sodium", kde=True, color="pink", ax=axs[2, 0])
sns.histplot(data=HeartFail, x="serum_creatinine", kde=True, color="blue", ax=axs[2, 1])
plt.show()
###### great site where I learned how to code these graphs:
###### https://www.python-graph-gallery.com/25-histogram-with-several-variables-seaborn

# %% [markdown]
# #### The above graphs show 6 of the Continuous IVs frequencies.The data shows a high amount of people in the study were inbetween 60 and 70 years old. The creatinine phosphokinase is positively skewed. The ejection fraction & platelets are slightly positively skewed. Serum sodium is negatively skewed. And lastly, serum creatinine is postively skewed.

# %%
sns.displot(HeartFail, x='time', hue = 'sex', col = 'DEATH_EVENT', kind='hist')

# %% [markdown]
# #### Above graph shows time variable indicating follow up days, for both men and women as well as if there was a death or survival.

# %% [markdown]
# #### Preparing for Decision Trees and Random Forest
# #### (This initial Decision Tree & Random Forest and using all 13 variables just for Exploration purposes. Our question prediction is based on biometric facters so the variable 'time' will be dropped in the analysis preceding this one.)
# #### Import Packages

# %%
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV

# %%
HeartFail.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# #### Data Wrangling

# %%
x = HeartFail.drop('DEATH_EVENT', axis=1)
y = HeartFail['DEATH_EVENT']

# %% [markdown]
# #### Test Train Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=76)

# %% [markdown]
# #### Creating Preliminary Decision Tree

# %%
decisionTree = DecisionTreeClassifier(random_state=76)
decisionTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=76)

# %% [markdown]
# #### Assessing the Model & Reading the Confusion Matrix

# %%
treePredictions = decisionTree.predict(x_test)

# %%
print(confusion_matrix(y_test, treePredictions))
# Out:
# [[51 11]
#  [13 15]]

# %% [markdown]
# ##### Confusion matrix shows 51 were predicted to not die and did not die, 11 were predicted to not die but did die, 13 were predicted to die but did not die, and 15 people were predicted to die who did die.

# %% [markdown]
# #### How well does the model fit?

# %%
print(classification_report(y_test, treePredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81        62
#            1       0.58      0.54      0.56        28
#
#     accuracy                           0.73        90
#    macro avg       0.69      0.68      0.68        90
# weighted avg       0.73      0.73      0.73        90

# %% [markdown]
# #### This shows that overall, the model is 73% accurate. The model was 80% accurate in not predicting a death, while 58% accurate in predicting a death.

# %% [markdown]
# #### Random Forest Data Wrangling

# %%
x = HeartFail.drop('DEATH_EVENT', axis=1)
y = HeartFail['DEATH_EVENT']

# %% [markdown]
# #### Test Train Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=76)

# %% [markdown]
# #### Preliminary Random Forest Model

# %%
forest = RandomForestClassifier(n_estimators=500, random_state=76)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=76)

# %% [markdown]
# #### Checking How Well Model Fits Data

# %%
forestPredictions = forest.predict(x_test)
print(confusion_matrix(y_test, forestPredictions))
print(classification_report(y_test, forestPredictions))
# Out:
# [[57  5]
#  [ 8 20]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        62
#            1       0.80      0.71      0.75        28
#
#     accuracy                           0.86        90
#    macro avg       0.84      0.82      0.83        90
# weighted avg       0.85      0.86      0.85        90

# %% [markdown]
# #### This model had higher accuracy. It is 86% accurate. Model is 88% accurate in predicting survival, while 80% accurate in predicting death due to heart failure. This confusion matrix also shows less prediction error than the previous confusion matrix, as only 8 and 5 values were not accurately predicted.

# %% [markdown]
# #### Hyperparameter and Number of Estimators

# %%
n_estimators_array = [1, 4, 5, 8, 10, 20, 50, 75, 100, 250, 500]
results = []
for n in n_estimators_array:
    forest = RandomForestClassifier(n_estimators=n, random_state=76)
    forest.fit(x_train, y_train)
    result = accuracy_score(y_test, forest.predict(x_test))
    results.append(result) 
    print(n, ':', result)
# Out:
# 1 : 0.8111111111111111
# 4 : 0.7222222222222222
# 5 : 0.7555555555555555
# 8 : 0.7777777777777778
# 10 : 0.8111111111111111
# 20 : 0.8333333333333334
# 50 : 0.8777777777777778
# 75 : 0.8555555555555555
# 100 : 0.8555555555555555
# 250 : 0.8666666666666667
# 500 : 0.8555555555555555

# %% [markdown]
# #### Plotting the Results

# %%
plt.plot(n_estimators_array, results)

# %% [markdown]
# #### 50 is optimal

# %% [markdown]
# #### Creating lists With Hyperparameter Values to Test: one list for three features: max_features, max_depth, and min_samples_leaf. Then creating a dictionary with the hyperparameter names as keys and list variables as values referred to as a grid.

# %%
# Number of features to consider at every split
max_features = ['auto', None, 'log2']
# Maximum number of levels in tree
max_depth = [10, 20, 30, 40, 50, 60, 70, 80, 90, None]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
random_grid = {'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_leaf': min_samples_leaf}
print(random_grid)
####code learned from DSO106 L3P7
# Out:
# {'max_features': ['auto', None, 'log2'], 'max_depth': [10, 20, 30, 40, 50, 60, 70, 80, 90, None], 'min_samples_leaf': [1, 2, 4]}

# %% [markdown]
# #### Running the Random Forest

# %%
rf = RandomForestClassifier(n_estimators=50)
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 90, cv = 3, random_state=42)
rf_random.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=50),
#                    n_iter=90,
#                    param_distributions={'max_depth': [10, 20, 30, 40, 50, 60,
#                                                       70, 80, 90, None],
#                                         'max_features': ['auto', None, 'log2'],
#                                         'min_samples_leaf': [1, 2, 4]},
#                    random_state=42)

# %% [markdown]
# #### Parameters:

# %%
#rf_random.best_params_
#the parameters provided here actually did not increase model accuracy

# %%
forest = RandomForestClassifier(n_estimators=50, min_samples_leaf=4, max_features="auto", max_depth=50)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=50, min_samples_leaf=4, n_estimators=50)

# %%
forestPredictions = forest.predict(x_test)
print(confusion_matrix(y_test, forestPredictions))
print(classification_report(y_test, forestPredictions))
# Out:
# [[60  2]
#  [ 8 20]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        62
#            1       0.91      0.71      0.80        28
#
#     accuracy                           0.89        90
#    macro avg       0.90      0.84      0.86        90
# weighted avg       0.89      0.89      0.88        90

# %% [markdown]
# #### The model overall accuracy is 89%.

# %% [markdown]
# #### Feature Importance: Determining the most influential variables contributing to heart failure in this dataset

# %%
feature_importances = pd.Series(forest.feature_importances_, index=x.columns)
feature_importances.sort_values(inplace=True, ascending=False)
print(feature_importances)
# Out:
# time                        0.408616
# serum_creatinine            0.162314
# ejection_fraction           0.138868
# age                         0.096151
# serum_sodium                0.062544
# platelets                   0.048889
# creatinine_phosphokinase    0.046743
# diabetes                    0.007930
# anaemia                     0.007747
# sex                         0.007240
# smoking                     0.007219
# high_blood_pressure         0.005737
# dtype: float64

# %% [markdown]
# #### Plotting Results

# %%
feature_importances.plot(kind='barh', figsize=(7,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### The results are very interesting as time, which is the follow up period in days, is the most influential variable. The next highly influential variables were serum creatinine, ejection fraction, age, platelets, creatinine phosphokinase, and serum sodium.  The least influential variables according to this data were gender, anaemia, diabetes, high blood pressure, and smoking.
# ## I ran the above analysis just to get a preliminary look at the data, Below I will be removing the 'time' variable in order to focus solely on which biometric features have the greatest influence in predicting heart failure.

# %%
HeartFail.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# #### Creating a dataframe without the 'time' variable:

# %%
HrtFail = HeartFail[['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'DEATH_EVENT']]

# %%
HrtFail.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  DEATH_EVENT
# 0        0            1
# 1        0            1
# 2        1            1
# 3        0            1
# 4        0            1

# %%
#### Now HrtFail will be the dataframe we use as the variable of 'time' has been removed

# %% [markdown]
# #### Correlation Matrix

# %%
HrtFail.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_5a1fb_row0_col0, #T_5a1fb_row1_col1, #T_5a1fb_row2_col2, #T_5a1fb_row3_col3, #T_5a1fb_row4_col4, #T_5a1fb_row5_col5, #T_5a1fb_row6_col6, #T_5a1fb_row7_col7, #T_5a1fb_row8_col8, #T_5a1fb_row9_col9, #T_5a1fb_row10_col10, #T_5a1fb_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col3, #T_5a1fb_row1_col2, #T_5a1fb_row2_col1, #T_5a1fb_row3_col9, #T_5a1fb_row4_col11, #T_5a1fb_row5_col9, #T_5a1fb_row6_col9, #T_5a1fb_row7_col8, #T_5a1fb_row8_col11, #T_5a1fb_row9_col3, #T_5a1fb_row10_col3, #T_5a1fb_row11_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col4, #T_5a1fb_row2_col7, #T_5a1fb_row7_col2, #T_5a1fb_row10_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col5, #T_5a1fb_row4_col2, #T_5a1fb_row5_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col6, #T_5a1fb_row5_col10, #T_5a1fb_row9_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col7, #T_5a1fb_row4_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5a1fb_row0_col8, #T_5a1fb_row3_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col9, #T_5a1fb_row1_col3, #T_5a1fb_row2_col3, #T_5a1fb_row7_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_5a1fb_row0_col11 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_5a1fb_row1_col0, #T_5a1fb_row4_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col5, #T_5a1fb_row6_col3, #T_5a1fb_row8_col5, #T_5a1fb_row9_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col6, #T_5a1fb_row2_col4, #T_5a1fb_row7_col6, #T_5a1fb_row8_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col7, #T_5a1fb_row9_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col8, #T_5a1fb_row8_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col9, #T_5a1fb_row10_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col10, #T_5a1fb_row6_col11, #T_5a1fb_row10_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_5a1fb_row1_col11, #T_5a1fb_row3_col6, #T_5a1fb_row8_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col0, #T_5a1fb_row5_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col8, #T_5a1fb_row4_col3, #T_5a1fb_row11_col3, #T_5a1fb_row11_col9 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5a1fb_row2_col11, #T_5a1fb_row8_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5a1fb_row3_col1, #T_5a1fb_row3_col2, #T_5a1fb_row3_col5, #T_5a1fb_row5_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_5a1fb_row3_col4, #T_5a1fb_row5_col1, #T_5a1fb_row9_col11, #T_5a1fb_row10_col2, #T_5a1fb_row10_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_5a1fb_row3_col7, #T_5a1fb_row4_col9 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5a1fb_row3_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_5a1fb_row3_col10, #T_5a1fb_row9_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_5a1fb_row3_col11, #T_5a1fb_row6_col2, #T_5a1fb_row6_col10, #T_5a1fb_row7_col10 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_5a1fb_row4_col0, #T_5a1fb_row11_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5a1fb_row4_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5a1fb_row4_col7, #T_5a1fb_row7_col1, #T_5a1fb_row11_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_5a1fb_row4_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5a1fb_row4_col10 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5a1fb_row5_col2, #T_5a1fb_row9_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_5a1fb_row5_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_5a1fb_row5_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_5a1fb_row5_col6, #T_5a1fb_row8_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_5a1fb_row5_col11, #T_5a1fb_row6_col8, #T_5a1fb_row7_col9, #T_5a1fb_row8_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_5a1fb_row6_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5a1fb_row6_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5a1fb_row6_col4, #T_5a1fb_row11_col6 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_5a1fb_row6_col5, #T_5a1fb_row7_col5, #T_5a1fb_row10_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_5a1fb_row6_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5a1fb_row7_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_5a1fb_row7_col3, #T_5a1fb_row10_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_5a1fb_row7_col11 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_5a1fb_row8_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5a1fb_row8_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_5a1fb_row8_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_5a1fb_row9_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5a1fb_row9_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_5a1fb_row9_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_5a1fb_row9_col10 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_5a1fb_row10_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_5a1fb_row10_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_5a1fb_row10_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_5a1fb_row11_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5a1fb_row11_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_5a1fb_row11_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5a1fb_row11_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5a1fb_row11_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a1fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a1fb_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_5a1fb_level0_col1" class="col_heading level0 col1" >anaemia</th>
#       <th id="T_5a1fb_level0_col2" class="col_heading level0 col2" >creatinine_phosphokinase</th>
#       <th id="T_5a1fb_level0_col3" class="col_heading level0 col3" >diabetes</th>
#       <th id="T_5a1fb_level0_col4" class="col_heading level0 col4" >ejection_fraction</th>
#       <th id="T_5a1fb_level0_col5" class="col_heading level0 col5" >high_blood_pressure</th>
#       <th id="T_5a1fb_level0_col6" class="col_heading level0 col6" >platelets</th>
#       <th id="T_5a1fb_level0_col7" class="col_heading level0 col7" >serum_creatinine</th>
#       <th id="T_5a1fb_level0_col8" class="col_heading level0 col8" >serum_sodium</th>
#       <th id="T_5a1fb_level0_col9" class="col_heading level0 col9" >sex</th>
#       <th id="T_5a1fb_level0_col10" class="col_heading level0 col10" >smoking</th>
#       <th id="T_5a1fb_level0_col11" class="col_heading level0 col11" >DEATH_EVENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a1fb_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_5a1fb_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_5a1fb_row0_col1" class="data row0 col1" >0.088</td>
#       <td id="T_5a1fb_row0_col2" class="data row0 col2" >-0.082</td>
#       <td id="T_5a1fb_row0_col3" class="data row0 col3" >-0.1</td>
#       <td id="T_5a1fb_row0_col4" class="data row0 col4" >0.06</td>
#       <td id="T_5a1fb_row0_col5" class="data row0 col5" >0.093</td>
#       <td id="T_5a1fb_row0_col6" class="data row0 col6"

# %% [markdown]
# #### Decision Tree

# %%
x = HrtFail.drop('DEATH_EVENT', axis=1)
y = HrtFail['DEATH_EVENT']

# %% [markdown]
# #### Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=76)

# %% [markdown]
# #### Creating Preliminary Decision Tree

# %%
decisionTree = DecisionTreeClassifier(random_state=76)
decisionTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=76)

# %% [markdown]
# #### Model Assessment

# %%
treePredictions = decisionTree.predict(x_test)
print(confusion_matrix(y_test, treePredictions))
print(classification_report(y_test, treePredictions))
# Out:
# [[49 13]
#  [10 18]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81        62
#            1       0.58      0.64      0.61        28
#
#     accuracy                           0.74        90
#    macro avg       0.71      0.72      0.71        90
# weighted avg       0.75      0.74      0.75        90

# %% [markdown]
# #### This model shows overall accuracy rate of 74%. It is 83% accurate in predicting survival, while 58% accurate in predicting a death due to heart failure.

# %% [markdown]
# #### Random Forest
# ##### Data Wrangling

# %%
x = HrtFail.drop('DEATH_EVENT', axis=1)
y = HrtFail['DEATH_EVENT']

# %% [markdown]
# #### Test Train Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=76)

# %% [markdown]
# #### Preliminary Random Forest Model

# %%
forest = RandomForestClassifier(n_estimators=500, random_state=76)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=76)

# %% [markdown]
# #### Evaluating Model Fit

# %%
forestPredictions = forest.predict(x_test)
print(confusion_matrix(y_test, forestPredictions))
print(classification_report(y_test, forestPredictions))
# Out:
# [[56  6]
#  [14 14]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85        62
#            1       0.70      0.50      0.58        28
#
#     accuracy                           0.78        90
#    macro avg       0.75      0.70      0.72        90
# weighted avg       0.77      0.78      0.77        90

# %% [markdown]
# #### Random Forest model shows overall 78% accuracy. It is 80% accurate in predicting survival and 70% accurate in predicting death due to heart failure.

# %% [markdown]
# #### Hyperparameter and Number of Estimators

# %%
n_estimators_array = [1, 4, 5, 8, 10, 20, 50, 75, 100, 250, 500]
results = []
for n in n_estimators_array:
    forest = RandomForestClassifier(n_estimators=n, random_state=76)
    forest.fit(x_train, y_train)
    result = accuracy_score(y_test, forest.predict(x_test))
    results.append(result) 
    print(n, ':', result)
# Out:
# 1 : 0.6777777777777778
# 4 : 0.7111111111111111
# 5 : 0.7111111111111111
# 8 : 0.7444444444444445
# 10 : 0.7555555555555555
# 20 : 0.7444444444444445
# 50 : 0.7222222222222222
# 75 : 0.7444444444444445
# 100 : 0.7555555555555555
# 250 : 0.7666666666666667
# 500 : 0.7777777777777778

# %%
plt.plot(n_estimators_array, results)

# %% [markdown]
# #### 500 is optimal

# %% [markdown]
# #### Creating lists With Hyperparameter Values to Test: one list for three features: max_features, max_depth, and min_samples_leaf. Then creating a dictionary with the hyperparameter names as keys and list variables as values.

# %%
# Number of features to consider at every split
max_features = ['auto', None, 'log2']
# Maximum number of levels in tree
max_depth = [10, 20, 30, 40, 50, 60, 70, 80, 90, None]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
random_grid = {'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_leaf': min_samples_leaf}
print(random_grid)
#Code learned from DSO106 L3P7
# Out:
# {'max_features': ['auto', None, 'log2'], 'max_depth': [10, 20, 30, 40, 50, 60, 70, 80, 90, None], 'min_samples_leaf': [1, 2, 4]}

# %%
rf = RandomForestClassifier(n_estimators=500)
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 90, cv = 3, random_state=42)

# %%
rf_random.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(n_estimators=500),
#                    n_iter=90,
#                    param_distributions={'max_depth': [10, 20, 30, 40, 50, 60,
#                                                       70, 80, 90, None],
#                                         'max_features': ['auto', None, 'log2'],
#                                         'min_samples_leaf': [1, 2, 4]},
#                    random_state=42)

# %% [markdown]
# #### Parameters:

# %%
#rf_random.best_params_
#recommended parameters were not yielding better model results

# %%
forest = RandomForestClassifier(n_estimators=500, min_samples_leaf=4, max_features="auto", max_depth=80)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=80, min_samples_leaf=4, n_estimators=500)

# %% [markdown]
# ##### Running the Model

# %%
forestPredictions = forest.predict(x_test)
print(confusion_matrix(y_test, forestPredictions))
print(classification_report(y_test, forestPredictions))
# Out:
# [[55  7]
#  [15 13]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.83        62
#            1       0.65      0.46      0.54        28
#
#     accuracy                           0.76        90
#    macro avg       0.72      0.68      0.69        90
# weighted avg       0.74      0.76      0.74        90

# %% [markdown]
# #### This model is overall 76% accurate. It is 79% accurate in predicting survival, while 65% accurate in predicting a death due to heart failure

# %% [markdown]
# #### Feature Importance

# %%
feature_importances = pd.Series(forest.feature_importances_, index=x.columns)
feature_importances.sort_values(inplace=True, ascending=False)
feature_importances
# Out:
# serum_creatinine            0.269679
# ejection_fraction           0.214237
# age                         0.150430
# serum_sodium                0.104334
# platelets                   0.094425
# creatinine_phosphokinase    0.088288
# diabetes                    0.019059
# anaemia                     0.017147
# sex                         0.014762
# smoking                     0.014322
# high_blood_pressure         0.013316
# dtype: float64

# %%
feature_importances.plot(kind='barh', figsize=(7,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Here the data shows that by just looking at biometric factors influencing heart failure, we see that the most influencial variable was serum creatinine followed by ejection fraction, age, serum sodium, platelets, and creatinine phosphokinase. The the categorial variables were diabetes, gender, anaemia, smoking, and high blood pressure.

# %% [markdown]
# ####### I am not a medical doctor. These thoughts are my own based on drawing inferences from the datasets. If you are concerned and have questions about your health in regards to these studies, please speak to a licensed medical professional-MP

# %% [markdown]
# #### Separating the most influential variables based on the feature importance for correlation matrix

# %%
HeartFail11 = HeartFail[['creatinine_phosphokinase', 'serum_sodium', 'platelets', 'age', 'ejection_fraction', 'serum_creatinine']]

# %%
HeartFail11.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_2cd50_row0_col0, #T_2cd50_row1_col1, #T_2cd50_row2_col2, #T_2cd50_row3_col3, #T_2cd50_row4_col4, #T_2cd50_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2cd50_row0_col1, #T_2cd50_row3_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_2cd50_row0_col2, #T_2cd50_row4_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_2cd50_row0_col3, #T_2cd50_row1_col5, #T_2cd50_row2_col3, #T_2cd50_row3_col0, #T_2cd50_row4_col0, #T_2cd50_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2cd50_row0_col4, #T_2cd50_row3_col1, #T_2cd50_row4_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_2cd50_row0_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_2cd50_row1_col0, #T_2cd50_row4_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2cd50_row1_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_2cd50_row1_col3, #T_2cd50_row2_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_2cd50_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_2cd50_row2_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_2cd50_row2_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2cd50_row2_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_2cd50_row3_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_2cd50_row3_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_2cd50_row4_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_2cd50_row5_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_2cd50_row5_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2cd50_row5_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_2cd50_row5_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cd50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cd50_level0_col0" class="col_heading level0 col0" >creatinine_phosphokinase</th>
#       <th id="T_2cd50_level0_col1" class="col_heading level0 col1" >serum_sodium</th>
#       <th id="T_2cd50_level0_col2" class="col_heading level0 col2" >platelets</th>
#       <th id="T_2cd50_level0_col3" class="col_heading level0 col3" >age</th>
#       <th id="T_2cd50_level0_col4" class="col_heading level0 col4" >ejection_fraction</th>
#       <th id="T_2cd50_level0_col5" class="col_heading level0 col5" >serum_creatinine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cd50_level0_row0" class="row_heading level0 row0" >creatinine_phosphokinase</th>
#       <td id="T_2cd50_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_2cd50_row0_col1" class="data row0 col1" >0.06</td>
#       <td id="T_2cd50_row0_col2" class="data row0 col2" >0.024</td>
#       <td id="T_2cd50_row0_col3" class="data row0 col3" >-0.082</td>
#       <td id="T_2cd50_row0_col4" class="data row0 col4" >-0.044</td>
#       <td id="T_2cd50_row0_col5" class="data row0 col5" >-0.016</td>
#     </tr>
#     <tr>
#       <th id="T_2cd50_level0_row1" class="row_heading level0 row1" >serum_sodium</th>
#       <td id="T_2cd50_row1_col0" class="data row1 col0" >0.06</td>
#       <td id="T_2cd50_row1_col1" class="data row1 col1" >1.0</td>
#       <td id="T_2cd50_row1_col2" class="data row1 col2" >0.062</td>
#       <td id="T_2cd50_row1_col3" class="data row1 col3" >-0.046</td>
#       <td id="T_2cd50_row1_col4" class="data row1 col4" >0.18</td>
#       <td id="T_2cd50_row1_col5" class="data row1 col5" >-0.19</td>
#     </tr>
#     <tr>
#       <th id="T_2cd50_level0_row2" class="row_heading level0 row2" >platelets</th>
#       <td id="T_2cd50_row2_col0" class="data row2 col0" >0.024</td>
#       <td id="T_2cd50_row2_col1" class="data row2 col1" >0.062</td>
#       <td id="T_2cd50_row2_col2" class="data row2 col2" >1.0</td>
#       <td id="T_2cd50_row2_col3" class="data row2 col3" >-0.052</td>
#       <td id="T_2cd50_row2_col4" class="data row2 col4" >0.072</td>
#       <td id="T_2cd50_row2_col5" class="data row2 col5" >-0.041</td>
#     </tr>
#     <tr>
#       <th id="T_2cd50_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_2cd50_row3_col0" class="data row3 col0" >-0.082</td>
#       <td id="T_2cd50_row3_col1" class="data row3 col1" >-0.046</td>
#       <td id="T_2cd50_row3_col2" class="data row3 col2" >-0.052</td>
#       <td id="T_2cd50_row3_col3" class="data row3 col3" >1.0</td>
#       <td id="T_2cd50_row3_col4" class="data row3 col4" >0.06</td>
#       <td id="T_2cd50_row3_col5" class="data row3 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_2cd50_level0_row4" class="row_heading level0 row4" >ejection_fraction</th>
#       <td id="T_2cd50_row4_col0" class="data row4 col0" >-0.044</td>
#       <td id="T_2cd50_row4_col1" class="data row4 col1" >0.18</td>
#       <td id="T_2cd50_row4_col2" class="data row4 col2" >0.072</td>
#       <td id="T_2cd50_row4_col3" class="data row4 col3" >0.06</td>
#       <td id="T_2cd50_row4_col4" class="data row4 col4" >1.0</td>
#       <td id="T_2cd50_row4_col5" class="data row4 col5" >-0.011</td>
#     </tr>
#     <tr>
#       <th id="T_2cd50_level0_row5" class="row_heading level0 row5" >serum_creatinine</th>
#       <td id="T_2cd50_row5_col0" class="data row5 col0" >-0.016</td>
#       <td id="T_2cd50_row5_col1" class="data row5 col1" >-0.19</td>
#       <td id="T_2cd50_row5_col2" class="data row5 col2" >-0.041</td>
#       <td id="T_2cd50_row5_col3" class="data row5 col3" >0.16</td>
#       <td id="T_2cd50_row5_col4" class="data row5 col4" >-0.011</td>
#       <td id="T_2cd50_row5_col5" class="data row5 col5" >1.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Scatterplot of Serum Creatinine and Serum Sodium

# %%
Plot = HeartFail11.plot.scatter(x='serum_creatinine', y='serum_sodium')
Plot.set_title("Serum Creatinine and Serum Sodium")
Plot.set_xlabel("Serum Creatinine")
Plot.set_ylabel("Serum Sodium")
# Out:
# Text(0, 0.5, 'Serum Sodium')

# %% [markdown]
# #### Scatterplot of Ejection Fraction and Serum Sodium

# %%
Plot = HeartFail11.plot.scatter(x='ejection_fraction', y='serum_sodium')
Plot.set_title("Ejection Fraction and Serum Sodium")
Plot.set_xlabel("Ejection Fraction")
Plot.set_ylabel("Serum Sodium")
# Out:
# Text(0, 0.5, 'Serum Sodium')

# %% [markdown]
# #### Scatterplot of Serum Creatinine and Ejection Fraction

# %%
Plot = HeartFail11.plot.scatter(x='serum_creatinine', y='ejection_fraction')
Plot.set_title("Serum Creatinine and Ejection Fraction")
Plot.set_xlabel("Serum Creatinine")
Plot.set_ylabel("Ejection Fraction")
# Out:
# Text(0, 0.5, 'Ejection Fraction')

# %%
sns.displot(HrtFail, x='creatinine_phosphokinase', hue = 'sex', col = 'DEATH_EVENT', kind='hist')

# %%
### Above is the death events with gender and creatinine phosphokinase

# %%
sns.displot(HrtFail, x='ejection_fraction', hue = 'sex', col = 'DEATH_EVENT', kind='hist')

# %%
#### This is the death events by gender for ejection fraction which was one of the top influential variables for heart failure
#### Here we can see that most of the deaths did have 40% or less EF but there were still some with normal EF levels so that confirms that other variables are at play here.

# %%
sns.displot(HrtFail, x='serum_creatinine', hue = 'sex', col = 'DEATH_EVENT', kind='hist')

# %% [markdown]
# #### Plot of platelets and gender looking at Death Event

# %%
sns.displot(HrtFail, x='platelets', hue = 'sex', col = 'DEATH_EVENT', kind='hist')

# %%
#### Looks like most people that died had normal platelet range, only a few had critical levels above 450k and less than 150k.

# %% [markdown]
# #### Joint Plot of Serum Creatinine and Serum Sodium

# %%
sns.jointplot(data= HeartFail, x="serum_creatinine", y="serum_sodium")

# %%
#### I hope you enjoyed this exploration/analysis of the heart failure dataset from UCI! ~Maria (Mia) Panos
